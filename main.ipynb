# %%
from  notification import Email,Sms,Push
from utils import mesajhavuzu

# %%
eposta=Email(mesajhavuzu())
numara=Sms(mesajhavuzu())
push1=Push(mesajhavuzu())

# %%
liste=[eposta,numara,push1]
for i in liste:
    try:
        i.send()
        print(i)
        print("-"*20)
    except:
        print("bildiriminiz gönderilirken bi hata oluştu")
# Out:
# email gönderildi: Yeni bildiriminiz var
# Yeni bildiriminiz var - 2026-02-21 02:51:46.679418
# --------------------
# sms gönderildi: Yeni bildiriminiz var
# Yeni bildiriminiz var - 2026-02-21 02:51:46.679496
# --------------------
# push bildirimi gönderildi : Mesaja bak işte rfk
# Mesaja bak işte rfk - 2026-02-21 02:51:46.679562
# --------------------
